# %%
from mlxtend.plotting import category_scatter
import pandas as pd

# %%
class_data=pd.read_csv('D:\AI\Code\Project_1_Trần_Minh_Long_2052154\Dataset_CSV\Problem3.csv')
class_data
# Out:
#     Feature 1  Feature 2     Class
# 0           2          2  class -1
# 1           3          3  class -1
# 2           4          4  class -1
# 3           5          5  class -1
# 4           4          6  class -1
# 5           3          7  class -1
# 6           4          8  class -1
# 7           5          9  class -1
# 8           6         10  class -1
# 9           6          2  class +1
# 10          7          3  class +1
# 11          8          4  class +1
# 12          9          5  class +1
# 13          8          6  class +1
# 14          7          7  class +1
# 15          7          8  class +1
# 16          7          9  class +1
# 17          8         10  class +1

# %%
fig = category_scatter(x='Feature 1', y='Feature 2', label_col='Class', 
                       data=class_data, legend_loc='upper left')
